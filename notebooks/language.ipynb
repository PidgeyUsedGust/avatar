# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd

# %%
nba = pd.read_csv("../data/raw/demo/nba.csv")
automobile = pd.read_csv("../data/raw/demo/automobile.csv", header=None)
titanic = pd.read_csv("../data/raw/demo/titanic.csv")

# %%
from avatar.language import WranglingLanguage
import avatar.settings

# %%
avatar.settings.verbose = True

# %%
language = WranglingLanguage()

# %%
transformations = language.transformations(automobile)
transformations
# Out:
# Finding transformations: 100%|██████████| 312/312 [00:00<00:00, 475.50it/s]
# [<avatar.language.WranglingTransformation at 0x12aa40f40>,
#  <avatar.language.WranglingTransformation at 0x12aa40f70>,
#  <avatar.language.WranglingTransformation at 0x12ac9d0d0>,
#  <avatar.language.WranglingTransformation at 0x12ac9d880>,
#  <avatar.language.WranglingTransformation at 0x12ac9dc10>,
#  <avatar.language.WranglingTransformation at 0x12ac9daf0>,
#  <avatar.language.WranglingTransformation at 0x12ac9deb0>,
#  <avatar.language.WranglingTransformation at 0x12ac9df40>,
#  <avatar.language.WranglingTransformation at 0x12ac83fa0>,
#  <avatar.language.WranglingTransformation at 0x12ac9df70>,
#  <avatar.language.WranglingTransformation at 0x12ac7ec40>,
#  <avatar.language.WranglingTransformation at 0x12ac7e580>,
#  <avatar.language.WranglingTransformation at 0x12aa22460>,
#  <avatar.language.WranglingTransformation at 0x12ac9a8b0>,
#  <avatar.language.WranglingTransformation at 0x12ac9ab80>,
#  <avatar.language.WranglingTransformation at 0x12aa3c5b0>,
#  <avatar.language.WranglingTransformation at 0x12aa3c6d0>,
#  <avatar.language.WranglingTransformation at 0x12aa3c850>,
#  <avatar.language.WranglingTransformation at 0x12aa3c9d0>,
#  <avatar.language.WranglingTransformation at 0x12aa3cb50>,
#  <avatar.language.WranglingTransformation at 0x12aa3ccd0>,
#  <avatar.language.WranglingTransformation at 0x12aa3cac0>,
#  <avatar.language.WranglingTransformation at 0x12aa3cbb0>,
#  <avatar.language.WranglingTransformation at 0x12aa3cf70>,
#  <avatar.language.WranglingTransformation at 0x12ac9dd90>,
#  <avatar.language.WranglingTransformation at 0x12aa3c700>,
#  <avatar.language.WranglingTransformation at 0x12aa3c3d0>,
#  <avatar.language.WranglingTransformation at 0x12aa3c7c0>,
#  <avatar.language.WranglingTransformation at 0x12aa3cfa0>,
#  <avatar.language.WranglingTransformation at 0x12aa3c100>,
#  <avatar.language.WranglingTransformation at 0x12aa3c310>,
#  <avatar.language.WranglingTransformation at 0x12aa3ceb0>,
#  <avatar.language.WranglingTransformation at 0x12aa3c940>,
#  <avatar.language.WranglingTransformation at 0x12ac9a9a0>,
#  <avatar.language.WranglingTransformation at 0x12ac9ad60>,
#  <avatar.language.WranglingTransformation at 0x12ac9ad90>,
#  <avatar.language.WranglingTransformation at 0x12aca5310>,
#  <avatar.language.WranglingTransformation at 0x12aca5040>,
#  <avatar.language.WranglingTransformation at 0x12aca55e0>,
#  <avatar.language.WranglingTransformation at 0x12aca5280>,
#  <avatar.language.WranglingTransformation at 0x12aca5760>,
#  <avatar.language.WranglingTransformation at 0x12aca50a0>,
#  <avatar.language.WranglingTransformation at 0x12aca52b0>,
#  <avatar.language.WranglingTransformation at 0x12aca54f0>,
#  <avatar.language.WranglingTransformation at 0x12aca5550>,
#  <avatar.language.WranglingTransformation at 0x12aca5670>,
#  <avatar.language.WranglingTransformation at 0x12aca5730>,
#  <avatar.language.WranglingTransformation at 0x12aca5790>,
#  <avatar.language.WranglingTransformation at 0x12aca57c0>,
#  <avatar.language.WranglingTransformation at 0x12aca5850>,
#  <avatar.language.WranglingTransformation at 0x12aca58e0>,
#  <avatar.language.WranglingTransformation at 0x12aca5970>,
#  <avatar.language.WranglingTransformation at 0x12aca5a00>,
#  <avatar.language.WranglingTransformation at 0x12aca5a90>,
#  <avatar.language.WranglingTransformation at 0x12ac9aaf0>,
#  <avatar.language.WranglingTransformation at 0x12ac7ec70>,
#  <avatar.language.WranglingTransformation at 0x12aca5400>,
#  <avatar.language.WranglingTransformation at 0x12aca5b20>,
#  <avatar.language.WranglingTransformation at 0x12aca5bb0>,
#  <avatar.language.WranglingTransformation at 0x12aca5c40>,
#  <avatar.language.WranglingTransformation at 0x12aca5df0>,
#  <avatar.language.WranglingTransformation at 0x12aca5fd0>,
#  <avatar.language.WranglingTransformation at 0x12ac98100>,
#  <avatar.language.WranglingTransformation at 0x12ac984f0>,
#  <avatar.language.WranglingTransformation at 0x12ac98610>,
#  <avatar.language.WranglingTransformation at 0x12ac98730>,
#  <avatar.language.WranglingTransformation at 0x12ac98850>,
#  <avatar.language.WranglingTransformation at 0x12ac98970>,
#  <avatar.language.WranglingTransformation at 0x12ac98b80>,
#  <avatar.language.WranglingTransformation at 0x12ac98df0>,
#  <avatar.language.WranglingTransformation at 0x12ac98ee0>,
#  <avatar.language.WranglingTransformation at 0x12ac9acd0>,
#  <avatar.language.WranglingTransformation at 0x12acaf220>]

# %%
new_titanic = language.expand(titanic)
new_titanic
# Out:
# Finding  transformations: 100%|██████████| 144/144 [00:00<00:00, 348.58it/s]
# Applying transformations: 100%|██████████| 48/48 [00:00<00:00, 133.16it/s]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... OneHot()(Parch)_5  \
# 0        0         A/5 21171   7.2500  ...                 0
# 1        0          PC 17599  71.2833  ...                 0
# 2        0  STON/O2. 3101282   7.9250  ...                 0
# 3        0            113803  53.1000  ...                 0
# 4        0            373450   8.0500  ...                 0
# ..     ...               ...      ...  ...               ...
# 886      0            211536  13.0000  ...                 0
# 887      0            112053  30.0000  ...                 0
# 888      2        W./C. 6607  23.4500  ...                 0
# 889      0            111369  30.0000  ...                 0
# 890      0            370376   7.7500  ...                 0
#
#     OneHot()(Parch)_6 OneHot()(Embarked)_C OneHot()(Embarked)_Q  \
# 0                   0                    0                    0
# 1                   0                    1                    0
# 2                   0                    0                    0
# 3                   0                    0                    0
# 4                   0                    0                    0
# ..                ...                  ...                  ...
# 886                 0                    0                    0
# 887                 0                    0                    0
# 888                 0                    0                    0
# 889                 0                    1                    0
# 890                 0                    0                    1
#
#     OneHot()(Embarked)_S                   NaN(Pernot, Mr. Rene)(Name)_Name  \
# 0                      1                            Braund, Mr. Owen Harris
# 1                      0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                      1                             Heikkinen, Miss. Laina
# 3                      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                      1                           Allen, Mr. William Henry
# ..                   ...                                                ...
# 886                    1                              Montvila, Rev. Juozas
# 887                    1                       Graham, Miss. Margaret Edith
# 888                    1           Johnston, Miss. Catherine Helen "Carrie"
# 889                    0                              Behr, Mr. Karl Howell
# 890                    0                                Dooley, Mr. Patrick
#
#          NaN(Somerton, Mr. Francis William)(Name)_Name  \
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
#     WordToNumber()(Ticket)_Ticket ModeImputation()(Cabin)_Cabin  \
# 0                             NaN                       B96 B98
# 1                             NaN                           C85
# 2                             NaN                       B96 B98
# 3                        113803.0                          C123
# 4                        373450.0                       B96 B98
# ..                            ...                           ...
# 886                      211536.0                       B96 B98
# 887                      112053.0                           B42
# 888                           NaN                       B96 B98
# 889                      111369.0                          C148
# 890                      370376.0                       B96 B98
#
#     ModeImputation()(Embarked)_Embarked
# 0                                     S
# 1                                     C
# 2                                     S
# 3                                     S
# 4                                     S
# ..                                  ...
# 886                                   S
# 887                                   S
# 888                                   S
# 889                                   C
# 890                                   Q
#
# [891 rows x 127 columns]
