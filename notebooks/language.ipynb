# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd

# %%
nba = pd.read_csv("../data/raw/demo/nba.csv")
display(nba.head())

automobile = pd.read_csv("../data/raw/demo/automobile.csv", header=None)
# automobile["brand"] = automobile[2].astype("category")
display(automobile.head())

titanic = pd.read_csv("../data/raw/demo/titanic.csv")
display(titanic.head())
# Out:
#   SEASON_ID TEAM_ABBREVIATION  PLAYER_ID                    PLAYER  NUM  \
# 0   2018-19               LAL    1628398                Kyle Kuzma    0
# 1   2018-19               LAL     203484  Kentavious Caldwell-Pope    1
# 2   2018-19               LAL    1628366                Lonzo Ball    2
# 3   2018-19               LAL    1628404                 Josh Hart    3
# 4   2018-19               LAL    1627936               Alex Caruso    4
#
#   POSITION HEIGHT  WEIGHT    BIRTH_DATE  PLAYER_AGE  ...  FG3_PCT  FTM  FTA  \
# 0        F    6-9     220  JUL 24, 1995          23  ...    0.303  188  250
# 1        G    6-5     205  FEB 18, 1993          26  ...    0.347  137  158
# 2        G    6-6     190  OCT 27, 1997          21  ...    0.329   20   48
# 3        G    6-5     215  MAR 06, 1995          24  ...    0.336   55   80
# 4        G   6-11     186  FEB 28, 1994          25  ...    0.480   51   64
#
#    FT_PCT  REB  AST  STL  BLK   PTS  a_lbl
# ...

# %%
from avatar.language import WranglingLanguage
from avatar.transformations import *

# %%
language = WranglingLanguage()

# %%
transformations = language.transformations(titanic)
for t in transformations:
    print(t)
# Out:
# Split(.)(Name)
# Split(()(Name)
# Split( ()(Name)
# Split("))(Name)
# Split(,)(Name)
# Split(, )(Name)
# Split(")(Name)
# Split(')(Name)
# Split( (")(Name)
# Split(-)(Name)
# Split(" )(Name)
# Split( )(Name)
# Split(. )(Name)
# Split(. ()(Name)
# Split(/)(Name)
# Split() (")(Name)
# Split() )(Name)
# Split())(Name)
# Split((")(Name)
# Split( ")(Name)
# Split() ()(Name)
# Split( )(Ticket)
# Split(.)(Ticket)
# Split(. )(Ticket)
# Split(./)(Ticket)
# Split(/)(Ticket)
# Split( )(Cabin)
# ExtractWord([Mrs, Miss, Rev, Dr, Master, Mr])(Name)
# ExtractWord([female, male])(Sex)
# ExtractWord([SOTON, P, O, PC, SC, C, A, LINE, CA, PP])(Ticket)
# ExtractWord([G, D, C, A, E, F, B])(Cabin)
# ExtractWord([S, Q, C])(Embarked)
# Lowercase()(Name)
# Lowercase()(Sex)
# Lowercase()(Ticket)
# Lowercase()(Cabin)
# Lowercase()(Embarked)
# OneHot()(Survived)
# OneHot()(Pclass)
# OneHot()(Sex)
# OneHot()(SibSp)
# OneHot()(Parch)
# OneHot()(Embarked)
# NaN(Pernot, Mr. Rene)(Name)
# ...

# %%
print(transformations[0])
transformations[0](titanic)
# Out:
# Split(.)(Name)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
print(transformations[1])
transformations[1](_)
# Out:
# Split( ")(Name)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...
