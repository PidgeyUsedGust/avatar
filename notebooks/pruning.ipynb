# %% [markdown]
# # Pruning
#
# In this notebook, we implement some unsupervised feature selection algorithms and hope that they're faster than learning the full model.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Data
#
# Load the titanic dataset and add some additional columns.

# %%
import avatar.language
import pandas as pd

titanic = pd.read_csv("../data/raw/demo/titanic.csv")
language = avatar.language.WranglingLanguage()

# %%
transformations = language.transformations(titanic)

# %%
import tqdm

titanic_new = titanic
for transformation in tqdm.tqdm(transformations):
    titanic_new = transformation(titanic_new)
titanic_new.shape
# Out:
# 100%|██████████| 67/67 [00:00<00:00, 148.83it/s]
# (891, 974)

# %%
titanic_new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... NaN(C78)(Cabin)_Cabin  \
# 0        0         A/5 21171   7.2500  ...                   NaN
# 1        0          PC 17599  71.2833  ...                   C85
# 2        0  STON/O2. 3101282   7.9250  ...                   NaN
# 3        0            113803  53.1000  ...                  C123
# 4        0            373450   8.0500  ...                   NaN
# ..     ...               ...      ...  ...                   ...
# 886      0            211536  13.0000  ...                   NaN
# 887      0            112053  30.0000  ...                   B42
# 888      2        W./C. 6607  23.4500  ...                   NaN
# 889      0            111369  30.0000  ...                  C148
# 890      0            370376   7.7500  ...                   NaN
#
#     NaN(E8)(Cabin)_Cabin NaN(C93)(Cabin)_Cabin NaN(B22)(Cabin)_Cabin  \
# 0                    NaN                   NaN                   NaN
# 1                    C85                   C85                   C85
# 2                    NaN                   NaN                   NaN
# 3                   C123                  C123                  C123
# 4                    NaN                   NaN                   NaN
# ..                   ...                   ...                   ...
# 886                  NaN                   NaN                   NaN
# 887                  B42                   B42                   B42
# 888                  NaN                   NaN                   NaN
# 889                 C148                  C148                  C148
# 890                  NaN                   NaN                   NaN
#
#     NaN(B18)(Cabin)_Cabin NaN(B35)(Cabin)_Cabin NaN(S)(Embarked)_Embarked  \
# 0                     NaN                   NaN                       NaN
# 1                     C85                   C85                         C
# 2                     NaN                   NaN                       NaN
# 3                    C123                  C123                       NaN
# 4                     NaN                   NaN                       NaN
# ..                    ...                   ...                       ...
# 886                   NaN                   NaN                       NaN
# 887                   B42                   B42                       NaN
# 888                   NaN                   NaN                       NaN
# 889                  C148                  C148                         C
# 890                   NaN                   NaN                         Q
#
#     NaN(C)(Embarked)_Embarked NaN(Q)(Embarked)_Embarked  \
# 0                           S                         S
# 1                         NaN                         C
# 2                           S                         S
# 3                           S                         S
# 4                           S                         S
# ..                        ...                       ...
# 886                         S                         S
# 887                         S                         S
# 888                         S                         S
# 889                       NaN                         C
# 890                         Q                       NaN
#
#     WordToNumber()(Ticket)_Ticket
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                        113803.0
# 4                        373450.0
# ..                            ...
# 886                      211536.0
# 887                      112053.0
# 888                           NaN
# 889                      111369.0
# 890                      370376.0
#
# [891 rows x 1146 columns]

# %% [markdown]
# ## Categocial pruning
#
# Prune columns that are categorical and contain too many different values.

# %%
from avatar.prune import CADPruner, NaNPruner

cadp = CADPruner(0.90)
nanp = NaNPruner(0.75)

titanic_new = nanp(cadp(titanic_new))
titanic_new
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked  ... NaN(A/4 48871)(Ticket)_Ticket  \
# 0           A/5 21171   7.2500        S  ...                     A/5 21171
# 1            PC 17599  71.2833        C  ...                      PC 17599
# 2    STON/O2. 3101282   7.9250        S  ...              STON/O2. 3101282
# 3              113803  53.1000        S  ...                        113803
# 4              373450   8.0500        S  ...                        373450
# ..                ...      ...      ...  ...                           ...
# 886            211536  13.0000        S  ...                        211536
# 887            112053  30.0000        S  ...                        112053
# 888        W./C. 6607  23.4500        S  ...                    W./C. 6607
# 889            111369  30.0000        C  ...                        111369
# 890            370376   7.7500        Q  ...                        370376
#
#     NaN(113572)(Ticket)_Ticket NaN(PC 17758)(Ticket)_Ticket  \
# 0                    A/5 21171                    A/5 21171
# 1                     PC 17599                     PC 17599
# 2             STON/O2. 3101282             STON/O2. 3101282
# 3                       113803                       113803
# 4                       373450                       373450
# ..                         ...                          ...
# 886                     211536                       211536
# 887                     112053                       112053
# 888                 W./C. 6607                   W./C. 6607
# 889                     111369                       111369
# 890                     370376                       370376
#
#     NaN(237736)(Ticket)_Ticket NaN(31027)(Ticket)_Ticket  \
# 0                    A/5 21171                 A/5 21171
# 1                     PC 17599                  PC 17599
# 2             STON/O2. 3101282          STON/O2. 3101282
# 3                       113803                    113803
# 4                       373450                    373450
# ..                         ...                       ...
# 886                     211536                    211536
# 887                     112053                    112053
# 888                 W./C. 6607                W./C. 6607
# 889                     111369                    111369
# 890                     370376                    370376
#
#     NaN(110465)(Ticket)_Ticket NaN(S)(Embarked)_Embarked  \
# 0                    A/5 21171                       NaN
# 1                     PC 17599                         C
# 2             STON/O2. 3101282                       NaN
# 3                       113803                       NaN
# 4                       373450                       NaN
# ..                         ...                       ...
# 886                     211536                       NaN
# 887                     112053                       NaN
# 888                 W./C. 6607                       NaN
# 889                     111369                         C
# 890                     370376                         Q
#
#     NaN(C)(Embarked)_Embarked NaN(Q)(Embarked)_Embarked  \
# 0                           S                         S
# 1                         NaN                         C
# 2                           S                         S
# 3                           S                         S
# 4                           S                         S
# ..                        ...                       ...
# 886                         S                         S
# 887                         S                         S
# 888                         S                         S
# 889                       NaN                         C
# 890                         Q                       NaN
#
#     WordToNumber()(Ticket)_Ticket
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                        113803.0
# 4                        373450.0
# ..                            ...
# 886                      211536.0
# 887                      112053.0
# 888                           NaN
# 889                      111369.0
# 890                      370376.0
#
# [891 rows x 1030 columns]

# %%
titanic.apply(lambda x: pd.factorize(x)[0]).corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007  0.018305  1.000000 -0.042939  0.120150
# Survived       -0.005007  1.000000  0.247845 -0.005007  0.543351  0.042743
# Pclass          0.018305  0.247845  1.000000  0.018305  0.118133  0.180735
# Name            1.000000 -0.005007  0.018305  1.000000 -0.042939  0.120150
# Sex            -0.042939  0.543351  0.118133 -0.042939  1.000000  0.009117
# Age             0.120150  0.042743  0.180735  0.120150  0.009117  1.000000
# SibSp          -0.031023 -0.136302 -0.149630 -0.031023 -0.046152  0.003777
# Parch           0.001206  0.086210 -0.000343  0.001206  0.242417  0.136160
# Ticket          0.760875 -0.047298  0.020431  0.760875 -0.132709  0.070385
# Fare            0.299982  0.191981  0.079498  0.299982  0.137725  0.114674
# Cabin           0.241918  0.270495  0.187437  0.241918  0.082104  0.165159
# Embarked       -0.030323  0.101849 -0.168809 -0.030323  0.111249 -0.152716
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked
# PassengerId -0.031023  0.001206  0.760875  0.299982  0.241918 -0.030323
# Survived    -0.136302  0.086210 -0.047298  0.191981  0.270495  0.101849
# Pclass      -0.149630 -0.000343  0.020431  0.079498  0.187437 -0.168809
# Name        -0.031023  0.001206  0.760875  0.299982  0.241918 -0.030323
# Sex         -0.046152  0.242417 -0.132709  0.137725  0.082104  0.111249
# Age          0.003777  0.136160  0.070385  0.114674  0.165159 -0.152716
# SibSp        1.000000  0.165255 -0.122426 -0.046556 -0.108709 -0.030612
# Parch        0.165255  1.000000 -0.262607  0.074306 -0.002761 -0.082982
# Ticket      -0.122426 -0.262607  1.000000  0.303257  0.212438 -0.020135
# Fare        -0.046556  0.074306  0.303257  1.000000  0.379659  0.077933
# Cabin       -0.108709 -0.002761  0.212438  0.379659  1.000000  0.017855
# Embarked    -0.030612 -0.082982 -0.020135  0.077933  0.017855  1.000000

# %% [markdown]
# ## Unsupervised Feature Selection
#
# We focus on filter methods as they are faster than wrappers. These methods typically use.

# %%
def to_numerical(df):
    """Make dataframe features numerical by 1H encoding."""
    ndf = pd.DataFrame()
    n2o = dict()
    for i, column in enumerate(df):
        if df[column].dtype == "object":
            # create new dataframe
            new = pd.get_dummies(df[column])
            ndf = pd.concat((ndf, new), axis=1)
            # map new column to old ones
            for new_column in new:
                n2o[new_column] = column
        else:
            ndf[column] = df[column]
            n2o[column] = column
    # make numerical
    n2o = {ndf.columns.get_loc(k): df.columns.get_loc(v) for k, v in n2o.items()}
    return ndf.values, n2o       
    

titanic_num, n2o = to_numerical(cadp(titanic_new))
titanic_num

# %% [markdown]
# ### Principal Feature Analysis
#
# Using [this implementation](https://stats.stackexchange.com/a/203978) based on the idea from [this paper](http://venom.cs.utsa.edu/dmz/techrep/2007/CS-TR-2007-011.pdf). Downside is that number of features needs to be chosen and all data has to be numerical.

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import StandardScaler
from collections import defaultdict


class PFA(object):
    
    def __init__(self, n_features, q=None):
        self.q = q
        self.n_features = n_features

    def fit(self, X):
    
        if not self.q:
            self.q = X.shape[1]

        # missing values
        X = np.nan_to_num(X)
            
        sc = StandardScaler()
        X = sc.fit_transform(X)

        pca = PCA(n_components=self.q).fit(X)
        A_q = pca.components_.T

        kmeans = KMeans(n_clusters=self.n_features).fit(A_q)
        clusters = kmeans.predict(A_q)
        cluster_centers = kmeans.cluster_centers_

        dists = defaultdict(list)
        for i, c in enumerate(clusters):
            dist = euclidean_distances([A_q[i, :]], [cluster_centers[c, :]])[0][0]
            dists[c].append((i, dist))

        self.indices_ = [sorted(f, key=lambda x: x[1])[0][0] for f in dists.values()]
        self.features_ = X[:, self.indices_]

# %%
pfa = PFA(n_features=50)
pfa.fit(titanic_num)

# %%
pfa.indices_
# Out:
# [472,
#  61,
#  17,
#  54,
#  306,
#  181,
#  506,
#  296,
#  439,
#  16,
#  151,
#  146,
#  387,
#  129,
#  366,
#  214,
#  596,
#  233,
#  33,
#  156,
#  475,
#  288,
#  58,
#  243,
#  64,
#  384,
#  282,
#  74,
#  76,
#  643,
#  800,
#  112,
#  257,
#  118,
#  136,
#  344,
#  687,
#  204,
#  582,
#  681,
#  287,
#  621,
#  298,
#  747,
#  404,
#  813,
#  457,
#  561,
#  589,
#  822]

# %% [markdown]
# Next, we have some algorithms from the [`skfeature`](http://featureselection.asu.edu/index.php) package.
#
# ### SPEC

# %%
from skfeature.function.similarity_based import SPEC

# %%
# specify the second ranking function which uses all except the 1st eigenvalue
kwargs = {'style': 0}

# obtain the scores of features
score = SPEC.spec(np.nan_to_num(titanic_num), **kwargs)

# %%
idx = SPEC.feature_ranking(score, **kwargs)
idx
# Out:
# array([287, 293, 372, 357, 127, 236, 481, 363, 651, 482, 659, 653, 183,
#         86, 382, 384, 181, 225, 495, 375, 374, 628, 489, 833, 458, 457,
#        406, 343, 179, 281, 252, 201, 452, 366, 291, 370, 429, 280, 572,
#        646, 475, 512, 220, 838, 469, 460, 184, 275, 500, 634, 380, 411,
#          3,   4, 837, 534, 650, 839, 315, 157, 625, 165, 472, 361,  84,
#        391, 214, 187, 526, 657, 282, 674,   1, 167, 832, 623, 519, 444,
#        450, 456, 533, 499, 195, 503, 390, 351, 399, 479, 560, 638, 529,
#        445, 501, 405,   6, 200, 368, 680, 133, 209, 564, 276, 491, 541,
#        318, 115, 454, 258, 285, 350, 316, 386,   7, 570,   2, 296, 376,
#          5, 354, 433, 829, 272, 667, 420, 627, 158, 125, 193, 319, 588,
#        544, 573, 109, 440, 520, 810, 178, 575, 689, 441, 410,   0, 196,
#        418, 655, 581, 266, 490, 486, 409, 455, 379, 295, 320, 547, 332,
#        191, 154, 213, 367, 346, 328, 682, 221, 446, 340, 687, 113, 207,
#        128, 640, 263, 447, 305, 349, 210, 333, 666, 253, 215, 106, 614,
#        741, 396, 535, 521, 553, 229, 108,  11, 303, 190,  53, 513, 261,
#        269, 761, 175, 180, 365, 478, 567, 517, 277, 569, 636, 317, 658,
#        265, 120, 808, 494, 335, 199, 419, 780, 352, 523, 442, 538, 453,
#        531, 677, 389, 568, 300, 203, 155, 546, 306, 301, 514, 476, 532,
#        373, 117, 806, 508, 362, 392, 516, 536, 471, 548, 400, 299, 126,
#        493, 670, 256, 631, 381, 644, 416, 274, 678, 561, 565, 552, 649,
#        288, 336, 313, 660, 428, 174,  85, 278, 422, 254, 148, 435, 230,
#        676, 188, 204, 637, 168, 314, 414, 235, 348, 467, 437, 647, 648,
#        549, 124, 555, 205, 563, 412, 359, 345, 273, 755, 417, 775, 511,
#        606,  13, 708, 836,  47, 630, 147, 621, 121, 831, 596, 749,  38,
#        331, 283, 753, 103, 257, 247, 383, 819,  93,  98, 704, 751,  44,
#        337, 739,  46, 334, 436, 378, 171, 661, 431, 817, 545, 698,  25,
#        488, 703,  50,  36, 813, 101, 777, 781, 620, 330, 473,  19, 742,
#        403, 559, 197, 759, 601, 298,  62, 792, 222,  89, 556, 143, 566,
#         28, 279, 803, 518, 693,  32, 770, 465, 324, 502,  10, 224, 718,
#        612, 240, 211, 746, 159, 286, 443, 597, 557, 602, 744, 150, 326,
#        725, 610, 307, 835,  79, 413, 766, 477, 192,  40, 711, 824, 177,
#        815, 643, 142, 814, 461,   9, 451, 140, 166, 699,  42, 592, 783,
#         71, 388, 239, 152, 583, 762, 730, 574, 752, 685, 212, 119,  45,
#        604, 771,   8, 616,  67, 764, 619, 123, 562,  99,  91, 613, 170,
#        206,  72, 721,  55, 302, 737,  41, 356, 675, 480, 134, 683, 407,
#        543, 809,  96,  31, 297, 700, 784,  49, 754, 772, 509, 622, 241,
#        464, 796,  29, 716, 688, 710, 632,  64, 785, 141, 664, 216, 825,
#         58, 798, 164, 558, 264, 146, 248, 289,  97, 709, 590, 774, 105,
#        551, 826, 705, 244,  95, 757, 182, 701,  20, 727, 820, 617,  70,
#        758, 760, 421, 311, 696, 598, 371, 599, 789, 325, 186,  23, 706,
#        712,  74, 734, 605, 802,  34,  43, 790, 782, 242, 415,  26, 795,
#         90,  59, 827, 756, 116,  27, 459, 145, 474, 344, 448, 169,  77,
#        697, 208, 149, 722, 401, 799, 427, 748, 107,  56, 504, 822, 728,
#        577, 763, 226, 695, 112, 804, 463, 800, 114, 153, 393,  17, 404,
#        338,  54, 217, 438, 694, 485, 268, 738,  68,  60, 137, 353, 690,
#         76,  87, 765, 163, 397, 308,  82, 719, 294, 423,  65, 692, 360,
#        537, 111, 723,  78, 586, 156,  21,  75, 681, 729, 249, 607,  83,
#        717, 767, 434, 778, 591, 540, 243, 218, 571, 131, 732, 668, 492,
#        539, 639, 497, 525,  18, 292, 284, 462, 786, 498, 656, 611, 321,
#         14, 823, 387, 259, 787,  94, 691,  52, 654, 144, 715,  69, 740,
#         48, 507, 246, 818,  80, 251, 665, 776,  92, 104, 807, 635, 816,
#         81, 724, 395, 510, 398, 189, 652, 805, 323, 176, 542, 506, 260,
#        527, 135,  22, 720,  16, 750, 231, 358, 234, 439, 408,  30, 743,
#        663, 138, 672, 232, 377, 327, 267, 679,  73, 172, 618, 528, 633,
#        769,  35, 487, 364, 589, 714, 309, 505, 219, 369, 609, 821,  66,
#        641, 245, 238, 550, 484, 329, 202, 673, 132, 579, 671, 430, 449,
#        811, 483, 600, 554, 794,  12, 585, 624, 735, 151, 733, 118, 402,
#        797,  63, 250, 322, 185,  57, 745, 736,  24, 228, 262, 227, 530,
#        426, 768, 100, 595, 432, 791, 304, 162, 812, 686, 496, 139,  51,
#        642, 669, 110, 801, 160, 468, 424, 779, 645,  37, 713, 223, 385,
#         61, 793, 747, 702, 615, 684, 237, 130, 522, 626, 576, 102, 271,
#        136, 290, 342, 524, 608,  88, 255, 578,  33, 828, 173, 161, 580,
#        270, 726, 593, 129, 194, 466, 339, 587, 233, 347, 122, 834, 773,
#         39, 312, 584, 594, 830, 310, 629, 788, 425, 515, 662, 582, 731,
#        355, 707,  15, 470, 198, 394, 603, 341])

# %% [markdown]
# ## Supervised

# %%
import time
from mercs.core import Mercs
from avatar.analysis import *

# %% [markdown]
# We sample random columns to generate a dataset in which there exists at least one row without NaN in order to make MERCS work.

# %%
sampler = UniformColumnSampler(titanic_new)
sampler.sample()
# Out:
#      Embarked  Split( )(Ticket)_1  NaN(male)(Sex)_Sex  \
# 0        True                True               False
# 1        True                True                True
# 2        True                True                True
# 3        True               False                True
# 4        True               False               False
# ..        ...                 ...                 ...
# 886      True               False               False
# 887      True               False                True
# 888      True                True                True
# 889      True               False               False
# 890      True               False               False
#
#      NaN(347088)(Ticket)_Ticket  NaN(3101295)(Ticket)_Ticket  \
# 0                          True                         True
# 1                          True                         True
# 2                          True                         True
# 3                          True                         True
# 4                          True                         True
# ..                          ...                          ...
# 886                        True                         True
# 887                        True                         True
# 888                        True                         True
# 889                        True                         True
# 890                        True                         True
#
#      NaN(349909)(Ticket)_Ticket  NaN(17421)(Ticket)_Ticket  \
# 0                          True                       True
# 1                          True                       True
# 2                          True                       True
# 3                          True                       True
# 4                          True                       True
# ..                          ...                        ...
# 886                        True                       True
# 887                        True                       True
# 888                        True                       True
# 889                        True                       True
# 890                        True                       True
#
#      NaN(19950)(Ticket)_Ticket  NaN(LINE)(Ticket)_Ticket  \
# 0                         True                      True
# 1                         True                      True
# 2                         True                      True
# 3                         True                      True
# 4                         True                      True
# ..                         ...                       ...
# 886                       True                      True
# 887                       True                      True
# 888                       True                      True
# 889                       True                      True
# 890                       True                      True
#
#      NaN(347742)(Ticket)_Ticket  ...  NaN(PC 17477)(Ticket)_Ticket  \
# 0                          True  ...                          True
# 1                          True  ...                          True
# 2                          True  ...                          True
# 3                          True  ...                          True
# 4                          True  ...                          True
# ..                          ...  ...                           ...
# 886                        True  ...                          True
# 887                        True  ...                          True
# 888                        True  ...                          True
# 889                        True  ...                          True
# 890                        True  ...                          True
#
#      NaN(WE/P 5735)(Ticket)_Ticket  NaN(367230)(Ticket)_Ticket  \
# 0                             True                        True
# 1                             True                        True
# 2                             True                        True
# 3                             True                        True
# 4                             True                        True
# ..                             ...                         ...
# 886                           True                        True
# 887                           True                        True
# 888                           True                        True
# 889                           True                        True
# 890                           True                        True
#
#      NaN(248738)(Ticket)_Ticket  NaN(26360)(Ticket)_Ticket  \
# 0                          True                       True
# 1                          True                       True
# 2                          True                       True
# 3                          True                       True
# 4                          True                       True
# ..                          ...                        ...
# 886                        True                       True
# 887                        True                       True
# 888                        True                       True
# 889                        True                       True
# 890                        True                       True
#
#      NaN(11767)(Ticket)_Ticket  NaN(17453)(Ticket)_Ticket  \
# 0                         True                       True
# 1                         True                       True
# 2                         True                       True
# 3                         True                       True
# 4                         True                       True
# ..                         ...                        ...
# 886                       True                       True
# 887                       True                       True
# 888                       True                       True
# 889                       True                       True
# 890                       True                       True
#
#      NaN(PC 17758)(Ticket)_Ticket  NaN(237736)(Ticket)_Ticket  \
# 0                            True                        True
# 1                            True                        True
# 2                            True                        True
# 3                            True                        True
# 4                            True                        True
# ..                            ...                         ...
# 886                          True                        True
# 887                          True                        True
# 888                          True                        True
# 889                          True                        True
# 890                          True                        True
#
#      NaN(31027)(Ticket)_Ticket
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
# ..                         ...
# 886                       True
# 887                       True
# 888                       True
# 889                       True
# 890                       True
#
# [891 rows x 42 columns]

# %%
wsampler = WeightedColumnSampler(titanic_new)
wsampler.weights
# Out:
# PassengerId                      0.000000
# Survived                         0.000000
# Pclass                           0.000000
# Sex                              0.000000
# Age                              0.796357
#                                    ...
# NaN(110465)(Ticket)_Ticket       0.106642
# NaN(S)(Embarked)_Embarked        0.995540
# NaN(C)(Embarked)_Embarked        0.790149
# NaN(Q)(Embarked)_Embarked        0.672245
# WordToNumber()(Ticket)_Ticket    0.836655
# Length: 1030, dtype: float64

# %%
pd.Series(0, index=titanic_new.columns)
# Out:
# PassengerId                      0
# Survived                         0
# Pclass                           0
# Sex                              0
# Age                              0
#                                 ..
# NaN(110465)(Ticket)_Ticket       0
# NaN(S)(Embarked)_Embarked        0
# NaN(C)(Embarked)_Embarked        0
# NaN(Q)(Embarked)_Embarked        0
# WordToNumber()(Ticket)_Ticket    0
# Length: 1030, dtype: int64

# %%
wsampler.weights / 2
# Out:
# PassengerId                      0.000000
# Survived                         0.000000
# Pclass                           0.000000
# Sex                              0.000000
# Age                              0.398178
#                                    ...
# NaN(110465)(Ticket)_Ticket       0.053321
# NaN(S)(Embarked)_Embarked        0.497770
# NaN(C)(Embarked)_Embarked        0.395074
# NaN(Q)(Embarked)_Embarked        0.336122
# WordToNumber()(Ticket)_Ticket    0.418327
# Length: 1030, dtype: float64

# %%
ssampler = SmartColumnSampler(titanic_new)
ssampler.smart_weights
# Out:
# PassengerId                      0
# Survived                         0
# Pclass                           0
# Name                             0
# Sex                              0
#                                 ..
# NaN(111426)(Ticket)_Ticket       0
# NaN(19996)(Ticket)_Ticket        0
# NaN(111369)(Ticket)_Ticket       0
# NaN(C111)(Cabin)_Cabin           0
# WordToNumber()(Ticket)_Ticket    0
# Length: 974, dtype: int64
# PassengerId                      0.000000
# Survived                         0.000000
# Pclass                           0.000000
# Name                             0.000000
# Sex                              0.000000
#                                    ...
# NaN(111426)(Ticket)_Ticket       0.000000
# NaN(19996)(Ticket)_Ticket        0.102065
# NaN(111369)(Ticket)_Ticket       0.000000
# NaN(C111)(Cabin)_Cabin           0.962093
# WordToNumber()(Ticket)_Ticket    0.800751
# Length: 974, dtype: float64
# PassengerId                      0.000000
# Survived                         0.000000
# Pclass                           0.000000
# Name                             0.000000
# Sex                              0.000000
#                                    ...
# NaN(111426)(Ticket)_Ticket       0.000000
# NaN(19996)(Ticket)_Ticket        0.051033
# NaN(111369)(Ticket)_Ticket       0.000000
# NaN(C111)(Cabin)_Cabin           0.481047
# WordToNumber()(Ticket)_Ticket    0.400376
# Length: 974, dtype: float64

# %%
titanic_new.Survived[4]
# Out:
# 0

# %%
titanic_mercs, nominal_attributes = to_mercs(titanic_new)
m_codes = make_m_codes(titanic_new, "Survived")
m_codes
# Out:
# array([[0., 1., 0., ..., 0., 0., 0.]])

# %%
cfg_mercs_stump = dict(
    # Induction
    max_depth=1,
    selection_algorithm="default",
    nb_targets=1,
    nb_iterations=1,
    n_jobs=1,
    # Inference
    inference_algorithm="own",
    prediction_algorithm="mi",
    max_steps=8,
    # Metadata
    nominal_attributes=nominal_attributes,
)

cfg_mercs_default = dict(
    # Induction
    max_depth=8,
    selection_algorithm="default",
    nb_targets=1,
    nb_iterations=1,
    n_jobs=1,
    # Inference
    inference_algorithm="own",
    prediction_algorithm="mi",
    max_steps=8,
    # Metadata
    nominal_attributes=nominal_attributes,
)

# %%
s = time.time()

# Train a MERCS-model with config above
clf = Mercs(**cfg_mercs_default)

# Nominal attributes has to be given at fit, all the rest can be done before
clf.fit(titanic_mercs,
        nominal_attributes=nominal_attributes,
        m_codes=m_codes)

e = time.time()
e - s

# %%
s = time.time()

# Train a MERCS-model with config above
clf = Mercs(**cfg_mercs_stump)

# Nominal attributes has to be given at fit, all the rest can be done before
clf.fit(titanic_mercs, nominal_attributes=nominal_attributes)

e = time.time()
e - s
# Out:
#         Only 0 samples available for training.
#         min_nb_samples is set to 10.
#         Therefore no training occured.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-22ed9fc7dbba> in <module>
#       5
#       6 # Nominal attributes has to be given at fit, all the rest can be done before
# ----> 7 clf.fit(titanic_mercs, nominal_attributes=nominal_attributes)
#       8
#       9 e = time.time()
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/mercs/core/Mercs.py in fit(self, X, y, m_codes, **kwargs)
#     292             self.evl_cfg["consider_imputations"] = False
#     293
# --> 294         self.m_score = self.evaluation_algorithm(
#     295             X, self.m_codes, self.m_list, self.i_list, **self.evl_cfg
#     296         )
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/mercs/algo/evaluation.py in base_evaluation(data, m_codes, m_list, i_list, random_state, test_size, per_attribute_normalization, consider_imputations, **kwargs)
#      38     else:
#      39         dummy_evaluation = _dummy_evaluation(m_codes)
# ---> 40         m_score = normalize_m_score(
#      41             m_score,
#      42             dummy_evaluation,
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/mercs/algo/evaluation.py in normalize_m_score(m_score, dummy_evaluation, per_attribute_normalization)
#      70         norm_m_score = minmax_scale(m_score, axis=0)
#      71     else:
# ---> 72         norm_m_score = minmax_scale(m_score.flat, axis=0).reshape(m_score.shape)
#      73
#      74     # Set zeroes again
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in minmax_scale(X, feature_range, axis, copy)
#     496     # Unlike the scaler object, this function allows 1d input.
#     497     # If copy is required, it will be done inside the scaler object.
# --> 498     X = check_array(X, copy=False, ensure_2d=False,
#     499                     dtype=FLOAT_DTYPES, force_all_finite='allow-nan')
#     500     original_ndim = X.ndim
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.local/share/virtualenvs/avatar-aQSVyw2m/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     649         n_samples = _num_samples(array)
#     650         if n_samples < ensure_min_samples:
# --> 651             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     652                              " minimum of %d is required%s."
#     653                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
print(titanic_mercs)
# Out:
# [[1.00000e+00 0.00000e+00 3.00000e+00 ... 1.00000e+00 1.00000e+00
#           nan]
#  [2.00000e+00 1.00000e+00 1.00000e+00 ...         nan 0.00000e+00
#           nan]
#  [3.00000e+00 1.00000e+00 3.00000e+00 ... 1.00000e+00 1.00000e+00
#           nan]
#  ...
#  [8.89000e+02 0.00000e+00 3.00000e+00 ... 1.00000e+00 1.00000e+00
#           nan]
#  [8.90000e+02 1.00000e+00 1.00000e+00 ...         nan 0.00000e+00
#   1.11369e+05]
#  [8.91000e+02 0.00000e+00 3.00000e+00 ... 0.00000e+00         nan
#   3.70376e+05]]
